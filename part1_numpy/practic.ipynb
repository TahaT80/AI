# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('1.jpg')

# %%
im = np.array(img)
im.shape
# Out:
# (267, 400, 3)

# %%
bus = im[85:230, 110:260, :]
b_p =np.pad(bus,((20,20),(20,20),(0,0)))
plt.imshow(b_p)

# %%
# -
im[80:85, 110:260] = (0,0,0)      
im[230:235, 110:260] = (0,0,0)  

# |
im[80:235, 105:110] = (0,0,0)      
im[80:235, 260:265] = (0,0,0) 
# im[85:230,110:260] = (255,0,0) 
# im[90:225,115:255] = (0,255,0) 
# im[95:220,120:250] = (0,0,255) 
# im[100:215,125:245] = (0,0,0) 
# im[105:210,130:240] = (255,255,255) 
plt.imshow(im)
