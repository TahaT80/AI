# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
x = np.arange(0,500)
y = 7*x**2 +3*x +12 + np.random.uniform(-5e4,5e4,(500,))

# %%
plt.scatter(x[::10],y[::10],marker='.')
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
model.coef_,model.intercept_
# Out:
# (array([3486.88509274]), np.float64(-287842.7539886079))

# %%
p = model.predict(x.reshape(-1,1))

# %%
plt.scatter(x[::10],y[::10],c='b',marker='.')
plt.plot(x[::10],p[::10],c='r')
plt.show()

# %%
model.score(x.reshape(-1,1),y)
# Out:
# 0.9355670457237438

# %%
mean_absolute_error(y,p)
# Out:
# 111733.70536278369

# %% [markdown]
# ----
#
# $ f(x) = \alpha x + \beta $
#
# $ f(x) = \alpha_1 x^2 + \alpha_2 X + \beta  $
#
# $ f(x) = \alpha_1 x_2 + \alpha_2 X_2 + \beta  $

# %%
df = pd.DataFrame({'X':x})
df
# Out:
#        X
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 495  495
# 496  496
# 497  497
# 498  498
# 499  499
#
# [500 rows x 1 columns]

# %%
df = pd.DataFrame({'X1':x,'X2':x**2})
df
# Out:
#       X1      X2
# 0      0       0
# 1      1       1
# 2      2       4
# 3      3       9
# 4      4      16
# ..   ...     ...
# 495  495  245025
# 496  496  246016
# 497  497  247009
# 498  498  248004
# 499  499  249001
#
# [500 rows x 2 columns]

# %%
model = LinearRegression()
model.fit(df.values,y)
# Out:
# LinearRegression()

# %%
model.coef_,model.intercept_
# Out:
# (array([30.78068914,  6.92606093]), np.float64(-986.0884893146576))

# %%
model.score(df.values,y)
# Out:
# 0.9970867247069287

# %%
p = model.predict(df.values)

# %%
mean_absolute_error(y,p)
# Out:
# 24085.673769374484

# %%
plt.scatter(x[::10],y[::10],c='b',marker='.')
plt.plot(x,p,c='r')
plt.show()

# %% [markdown]
# ## Polynomial Feature

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)
poly.fit(x.reshape(-1,1))
X_p = poly.transform(x.reshape(-1,1))
X_p

# ردیف 1 همش یک
# ستون 2 عدد
# ستون 3 به توان 2
# Out:
# array([[1.00000e+00, 0.00000e+00, 0.00000e+00],
#        [1.00000e+00, 1.00000e+00, 1.00000e+00],
#        [1.00000e+00, 2.00000e+00, 4.00000e+00],
#        ...,
#        [1.00000e+00, 4.97000e+02, 2.47009e+05],
#        [1.00000e+00, 4.98000e+02, 2.48004e+05],
#        [1.00000e+00, 4.99000e+02, 2.49001e+05]], shape=(500, 3))

# %%
#fit_intercept=False  عرض از مبدا رو حساب کنه

model = LinearRegression(fit_intercept=False)
model.fit(X_p,y)
# Out:
# LinearRegression(fit_intercept=False)

# %%
model.score(X_p,y)
# Out:
# 0.9970867247069287
