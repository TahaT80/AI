# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits

from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score

# %%
x,y = load_digits(return_X_y=True)

# %%
X_new = x[:,:]
inertias = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(X_new)
    inertias.append(model.inertia_)  # فاصله عدد ها

# %%
plt.title('Elbow')
plt.plot(np.arange(2,20),inertias)
plt.xticks(np.arange(2,20));

# %%
res = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(x)
    p = model.predict(x)
    res.append((i ,silhouette_score(x,p)))

res
# Out:
# [(2, np.float64(0.10349811481998497)),
#  (3, np.float64(0.11514813474967336)),
#  (4, np.float64(0.1314641880679401)),
#  (5, np.float64(0.12909104503152835)),
#  (6, np.float64(0.1457275734645522)),
#  (7, np.float64(0.16300264419113963)),
#  (8, np.float64(0.1751877927638062)),
#  (9, np.float64(0.1892008228063148)),
#  (10, np.float64(0.15788025297545186)),
#  (11, np.float64(0.16715589082547)),
#  (12, np.float64(0.1806665388628127)),
#  (13, np.float64(0.18517670468588374)),
#  (14, np.float64(0.16210382987272384)),
#  (15, np.float64(0.16484601153910944)),
#  (16, np.float64(0.17979180607863227)),
#  (17, np.float64(0.1676645316230027)),
#  (18, np.float64(0.1857282543076375)),
#  (19, np.float64(0.1501787858065301))]

# %%
max(res,key=lambda x :x[1])
# Out:
# (9, np.float64(0.1892008228063148))

# %%
model = KMeans(n_clusters=9)
model.fit(x)
# Out:
# KMeans(n_clusters=9)

# %%
for i in range(len(model.cluster_centers_)):
    plt.subplot(3,3,i+1)
    plt.imshow(model.cluster_centers_[i].reshape(8,8),'gray')
