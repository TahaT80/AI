# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits

from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score

# %%
x,y = load_digits(return_X_y=True)

# %%
X_new = x[:,:]
inertias = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(X_new)
    inertias.append(model.inertia_)  # فاصله عدد ها

# %%
plt.title('Elbow')
plt.plot(np.arange(2,20),inertias)
plt.xticks(np.arange(2,20));

# %%
res = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(x)
    p = model.predict(x)
    res.append((i ,silhouette_score(x,p)))

res
# Out:
# [(2, np.float64(0.10190937235347243)),
#  (3, np.float64(0.1157908676036222)),
#  (4, np.float64(0.1270052068746415)),
#  (5, np.float64(0.13704552607097645)),
#  (6, np.float64(0.14705434198987918)),
#  (7, np.float64(0.164860419960862)),
#  (8, np.float64(0.17757470190075914)),
#  (9, np.float64(0.18908575283471507)),
#  (10, np.float64(0.1823250607511673)),
#  (11, np.float64(0.18088664755119604)),
#  (12, np.float64(0.18522221429242333)),
#  (13, np.float64(0.18118152889967812)),
#  (14, np.float64(0.18805882128767118)),
#  (15, np.float64(0.17280453196008916)),
#  (16, np.float64(0.17847632677954545)),
#  (17, np.float64(0.17609144249041786)),
#  (18, np.float64(0.16567412308728793)),
#  (19, np.float64(0.1590472631334346))]

# %%
max(res,key=lambda x :x[1])
# Out:
# (9, np.float64(0.18908575283471507))
