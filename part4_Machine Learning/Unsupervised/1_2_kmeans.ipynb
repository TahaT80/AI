# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits

from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score

# %%
x,y = load_digits(return_X_y=True)

# %%
X_new = x[:,:]
inertias = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(X_new)
    inertias.append(model.inertia_)  # فاصله عدد ها

# %%
plt.title('Elbow')
plt.plot(np.arange(2,20),inertias)
plt.xticks(np.arange(2,20));

# %%
res = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(x)
    p = model.predict(x)
    res.append((i ,silhouette_score(x,p)))

res
# Out:
# [(2, np.float64(0.11832841100655983)),
#  (3, np.float64(0.12525406853283574)),
#  (4, np.float64(0.1283315149692929)),
#  (5, np.float64(0.1376384893330496)),
#  (6, np.float64(0.14650676933242104)),
#  (7, np.float64(0.15318170353901533)),
#  (8, np.float64(0.17881260284677253)),
#  (9, np.float64(0.1534993124177005)),
#  (10, np.float64(0.18214964541340517)),
#  (11, np.float64(0.17955339113263216)),
#  (12, np.float64(0.16656029290592933)),
#  (13, np.float64(0.18112274319493202)),
#  (14, np.float64(0.15944772137151303)),
#  (15, np.float64(0.1717962938029567)),
#  (16, np.float64(0.18112836935849952)),
#  (17, np.float64(0.16894844082721916)),
#  (18, np.float64(0.16478593990976706)),
#  (19, np.float64(0.15691265657971257))]

# %%
max(res,key=lambda x :x[1])
# Out:
# (10, np.float64(0.18214964541340517))

# %%
model = KMeans(n_clusters=10)
model.fit(x)
# Out:
# KMeans(n_clusters=10)

# %%
for i in range(10):
    plt.subplot(4,3,i+1)
    plt.imshow(model.cluster_centers_[i].reshape(8,8),'gray')
