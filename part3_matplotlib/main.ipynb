# %%
import matplotlib.pyplot as plt

# %% [markdown]
# کد پایین یعنی نمودار داخل همین اجرا میشه و پنجره جدید باز نمیکنه

# %%
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [2, 3, 4, 6, 3, 2, 6, 7, 8]

# plt.plot(x, y,'*', color="green")
plt.plot(x, y,marker='*', color="green")
plt.title("plot")
plt.xlabel('tahaX')
plt.ylabel('tahay')
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.bar(x, y, color="red")
plt.title("bar")
plt.xlabel("color")
plt.ylabel("count")
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.pie(y, labels=x, autopct="%1.1f%%", colors=["red", "green", "blue", "orange"])
plt.title("example")

plt.show()

# %%
import numpy as np

x = np.random.rand(1000,1)

plt.hist(x,bins=5)
plt.show()

# %%
x = np.random.rand(64,64)
plt.imshow(x ,cmap=('hot'))
plt.colorbar()
plt.show()

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

# %%
plt.plot(x,y)

# %%
plt.plot(y)   # مقدار تولید میشه با کمک
            # Arange

# %%
plt.plot(x,y,'o-r')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.savefig('out.png')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.legend(['$Sin(x)$','Cos'])
plt.title('some plots')
plt.xlabel('values')
plt.ylabel('$Sin & Cos$')
plt.grid(which='both')
plt.xlim(0,360)
plt.ylim(-1,1)
plt.axis('on');  # data kenar jadval

# %%
data = np.random.uniform(1,10,(100,2))
plt.plot(data[:,0],data[:,1])

# %%
data = np.random.uniform(1,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
data = np.random.normal(0,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
y = np.random.normal(0,10,(1000))
x = np.arange(1000)
plt.scatter(x,y ,marker='v',s=50,c='#c10099',alpha=0.5)

# plt.plot(x,np.full((1000,),0) ,'r')
plt.plot([0,1000],[0,0],'r')
plt.plot([0,1000],[10,10],'m--')
plt.plot([0,1000],[-10,-10],'m--')
plt.xlim((0,1000))
# Out:
# (0.0, 1000.0)

# %%
x = np.array([1, 5, 8, 12])
y = np.array([-2, -3, 5, 9])

plt.scatter(x, y, marker="o", s=[23, 156, 288, 399], c=["r", "b", "#FF0000", "y"])

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

plt.scatter(x,y ,c=['r','b']*25)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

# color map
# https://matplotlib.org/stable/users/explain/colors/colormaps.html


plt.scatter(x,y ,c=np.arange(50),cmap='plasma')

# %%
x= np.linspace(0,360,500)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(500),cmap='hsv')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(50),cmap='hsv',vmin=0,vmax=100)

# plt.xticks(np.arange(0,360,10),rotation=90)
# plt.xticks(np.arange(0,360,10),minor=True,rotation=90)
plt.xticks((0,360,10),('A','B','C'))
# Out:
# ([<matplotlib.axis.XTick at 0x19e150c5590>,
#   <matplotlib.axis.XTick at 0x19e150c79d0>,
#   <matplotlib.axis.XTick at 0x19e15104190>],
#  [Text(0, 0, 'A'), Text(360, 0, 'B'), Text(10, 0, 'C')])

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
plt.bar(x,y,bottom=10)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
bottom = np.random.uniform(0,20,(10))

plt.bar(x,y,bottom=bottom)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
left = np.random.uniform(0,20,(10))

plt.barh(x,y,left=left)
# plt.xticks([1,2,3])
# Out:
# <BarContainer object of 10 artists>

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins
#         112.40233595,  116.24657884,  120.09082174,  123.93506464,
#         127.77930753,  131.62355043,  135.46779333,  139.31203622,
#         143.15627912,  147.00052202,  150.84476492,  154.68900781,
#         158.53325071,  162.37749361,  166.2217365 ,  170.0659794 ,
#         173.9102223 ,  177.75446519,  181.59870809,  185.44295099,
#         189.28719389,  193.13143678,  196.97567968,  200.81992258,
#         204.66416547,  208.50840837,  212.35265127,  216.19689416,
#         220.04113706,  223.88537996,  227.72962285,  231.57386575,
#         235.41810865,  239.26235155,  243.10659444,  246.95083734,
#         250.79508024,  254.63932313,  258.48356603,  262.32780893,
#         266.17205182,  270.01629472,  273.86053762,  277.70478051,
#         281.54902341,  285.39326631,  289.23750921,  293.0817521 ,
#         296.925995  ,  300.7702379 ,  304.61448079,  308.45872369,
#         312.30296659,  316.14720948,  319.99145238,  323.83569528,
#         327.67993817,  331.52418107,  335.36842397,  339.21266687,
#         343.05690976,  346.90115266,  350.74539556,  354.58963845,
#         358.43388135,  362.27812425,  366.12236714,  369.96661004,
#         373.81085294])

# %%
out[2]
# Out:
# <BarContainer object of 200 artists>

# %%
out[2].get_children()  # میتونی تک تک اون کندل هارو بگیری
# Out:
# [<matplotlib.patches.Rectangle at 0x19e163da490>,
#  <matplotlib.patches.Rectangle at 0x19e163da5d0>,
#  <matplotlib.patches.Rectangle at 0x19e163da710>,
#  <matplotlib.patches.Rectangle at 0x19e163da850>,
#  <matplotlib.patches.Rectangle at 0x19e163da990>,
#  <matplotlib.patches.Rectangle at 0x19e163daad0>,
#  <matplotlib.patches.Rectangle at 0x19e163dac10>,
#  <matplotlib.patches.Rectangle at 0x19e163dad50>,
#  <matplotlib.patches.Rectangle at 0x19e163dae90>,
#  <matplotlib.patches.Rectangle at 0x19e163dafd0>,
#  <matplotlib.patches.Rectangle at 0x19e163db110>,
#  <matplotlib.patches.Rectangle at 0x19e163db250>,
#  <matplotlib.patches.Rectangle at 0x19e163db390>,
#  <matplotlib.patches.Rectangle at 0x19e163db4d0>,
#  <matplotlib.patches.Rectangle at 0x19e163db610>,
#  <matplotlib.patches.Rectangle at 0x19e163db750>,
#  <matplotlib.patches.Rectangle at 0x19e163db890>,
#  <matplotlib.patches.Rectangle at 0x19e163db9d0>,
#  <matplotlib.patches.Rectangle at 0x19e163dbb10>,
#  <matplotlib.patches.Rectangle at 0x19e163dbc50>,
#  <matplotlib.patches.Rectangle at 0x19e163dbd90>,
#  <matplotlib.patches.Rectangle at 0x19e163dbed0>,
#  <matplotlib.patches.Rectangle at 0x19e16420050>,
#  <matplotlib.patches.Rectangle at 0x19e16420190>,
#  <matplotlib.patches.Rectangle at 0x19e164202d0>,
#  <matplotlib.patches.Rectangle at 0x19e16420410>,
#  <matplotlib.patches.Rectangle at 0x19e16420550>,
#  <matplotlib.patches.Rectangle at 0x19e16420690>,
#  <matplotlib.patches.Rectangle at 0x19e164207d0>,
#  <matplotlib.patches.Rectangle at 0x19e16420910>,
#  <matplotlib.patches.Rectangle at 0x19e16420a50>,
#  <matplotlib.patches.Rectangle at 0x19e16420b90>,
#  <matplotlib.patches.Rectangle at 0x19e16420f50>,
#  <matplotlib.patches.Rectangle at 0x19e16421310>,
#  <matplotlib.patches.Rectangle at 0x19e16421450>,
#  <matplotlib.patches.Rectangle at 0x19e16421590>,
#  <matplotlib.patches.Rectangle at 0x19e164216d0>,
#  <matplotlib.patches.Rectangle at 0x19e16421810>,
#  <matplotlib.patches.Rectangle at 0x19e16421950>,
#  <matplotlib.patches.Rectangle at 0x19e16421a90>,
#  <matplotlib.patches.Rectangle at 0x19e16420e10>,
#  <matplotlib.patches.Rectangle at 0x19e164211d0>,
#  <matplotlib.patches.Rectangle at 0x19e16421090>,
#  <matplotlib.patches.Rectangle at 0x19e16420cd0>,
#  <matplotlib.patches.Rectangle at 0x19e16421bd0>,
#  <matplotlib.patches.Rectangle at 0x19e16421d10>,
#  <matplotlib.patches.Rectangle at 0x19e16421e50>,
#  <matplotlib.patches.Rectangle at 0x19e16421f90>,
#  <matplotlib.patches.Rectangle at 0x19e164220d0>,
#  <matplotlib.patches.Rectangle at 0x19e16422210>,
#  <matplotlib.patches.Rectangle at 0x19e16422350>,
#  <matplotlib.patches.Rectangle at 0x19e16422490>,
#  <matplotlib.patches.Rectangle at 0x19e164225d0>,
#  <matplotlib.patches.Rectangle at 0x19e16422710>,
#  <matplotlib.patches.Rectangle at 0x19e16422850>,
#  <matplotlib.patches.Rectangle at 0x19e16422990>,
#  <matplotlib.patches.Rectangle at 0x19e16422ad0>,
#  <matplotlib.patches.Rectangle at 0x19e16422c10>,
#  <matplotlib.patches.Rectangle at 0x19e16422d50>,
#  <matplotlib.patches.Rectangle at 0x19e16422e90>,
#  <matplotlib.patches.Rectangle at 0x19e16422fd0>,
#  <matplotlib.patches.Rectangle at 0x19e16423110>,
#  <matplotlib.patches.Rectangle at 0x19e16423250>,
#  <matplotlib.patches.Rectangle at 0x19e16423390>,
#  <matplotlib.patches.Rectangle at 0x19e164234d0>,
#  <matplotlib.patches.Rectangle at 0x19e16423610>,
#  <matplotlib.patches.Rectangle at 0x19e16423750>,
#  <matplotlib.patches.Rectangle at 0x19e16423890>,
#  <matplotlib.patches.Rectangle at 0x19e164239d0>,
#  <matplotlib.patches.Rectangle at 0x19e16423b10>,
#  <matplotlib.patches.Rectangle at 0x19e16423c50>,
#  <matplotlib.patches.Rectangle at 0x19e16423d90>,
#  <matplotlib.patches.Rectangle at 0x19e16423ed0>,
#  <matplotlib.patches.Rectangle at 0x19e16478050>,
#  <matplotlib.patches.Rectangle at 0x19e16478190>,
#  <matplotlib.patches.Rectangle at 0x19e164782d0>,
#  <matplotlib.patches.Rectangle at 0x19e16478410>,
#  <matplotlib.patches.Rectangle at 0x19e16478550>,
#  <matplotlib.patches.Rectangle at 0x19e16478690>,
#  <matplotlib.patches.Rectangle at 0x19e164787d0>,
#  <matplotlib.patches.Rectangle at 0x19e16478910>,
#  <matplotlib.patches.Rectangle at 0x19e16478a50>,
#  <matplotlib.patches.Rectangle at 0x19e16478b90>,
#  <matplotlib.patches.Rectangle at 0x19e16478cd0>,
#  <matplotlib.patches.Rectangle at 0x19e16478e10>,
#  <matplotlib.patches.Rectangle at 0x19e16478f50>,
#  <matplotlib.patches.Rectangle at 0x19e16479090>,
#  <matplotlib.patches.Rectangle at 0x19e164791d0>,
#  <matplotlib.patches.Rectangle at 0x19e16479310>,
#  <matplotlib.patches.Rectangle at 0x19e16479450>,
#  <matplotlib.patches.Rectangle at 0x19e16479590>,
#  <matplotlib.patches.Rectangle at 0x19e164796d0>,
#  <matplotlib.patches.Rectangle at 0x19e16479810>,
#  <matplotlib.patches.Rectangle at 0x19e16479950>,
#  <matplotlib.patches.Rectangle at 0x19e16479a90>,
#  <matplotlib.patches.Rectangle at 0x19e16479bd0>,
#  <matplotlib.patches.Rectangle at 0x19e16479d10>,
#  <matplotlib.patches.Rectangle at 0x19e16479e50>,
#  <matplotlib.patches.Rectangle at 0x19e16479f90>,
#  <matplotlib.patches.Rectangle at 0x19e1647a0d0>,
#  <matplotlib.patches.Rectangle at 0x19e1647a210>,
#  <matplotlib.patches.Rectangle at 0x19e1647a350>,
#  <matplotlib.patches.Rectangle at 0x19e1647a490>,
#  <matplotlib.patches.Rectangle at 0x19e1647a5d0>,
#  <matplotlib.patches.Rectangle at 0x19e1647a710>,
#  <matplotlib.patches.Rectangle at 0x19e1647a850>,
#  <matplotlib.patches.Rectangle at 0x19e1647a990>,
#  <matplotlib.patches.Rectangle at 0x19e1647aad0>,
#  <matplotlib.patches.Rectangle at 0x19e1647ac10>,
#  <matplotlib.patches.Rectangle at 0x19e1647ad50>,
#  <matplotlib.patches.Rectangle at 0x19e1647ae90>,
#  <matplotlib.patches.Rectangle at 0x19e1647afd0>,
#  <matplotlib.patches.Rectangle at 0x19e1647b110>,
#  <matplotlib.patches.Rectangle at 0x19e1647b250>,
#  <matplotlib.patches.Rectangle at 0x19e1647b390>,
#  <matplotlib.patches.Rectangle at 0x19e1647b4d0>,
#  <matplotlib.patches.Rectangle at 0x19e1647b610>,
#  <matplotlib.patches.Rectangle at 0x19e1647b750>,
#  <matplotlib.patches.Rectangle at 0x19e1647b890>,
#  <matplotlib.patches.Rectangle at 0x19e1647b9d0>,
#  <matplotlib.patches.Rectangle at 0x19e1647bb10>,
#  <matplotlib.patches.Rectangle at 0x19e1647bc50>,
#  <matplotlib.patches.Rectangle at 0x19e1647bd90>,
#  <matplotlib.patches.Rectangle at 0x19e1647bed0>,
#  <matplotlib.patches.Rectangle at 0x19e164d8050>,
#  <matplotlib.patches.Rectangle at 0x19e164d8190>,
#  <matplotlib.patches.Rectangle at 0x19e164d82d0>,
#  <matplotlib.patches.Rectangle at 0x19e164d8410>,
#  <matplotlib.patches.Rectangle at 0x19e164d8550>,
#  <matplotlib.patches.Rectangle at 0x19e164d8690>,
#  <matplotlib.patches.Rectangle at 0x19e164d87d0>,
#  <matplotlib.patches.Rectangle at 0x19e164d8910>,
#  <matplotlib.patches.Rectangle at 0x19e164d8a50>,
#  <matplotlib.patches.Rectangle at 0x19e164d8b90>,
#  <matplotlib.patches.Rectangle at 0x19e164d8cd0>,
#  <matplotlib.patches.Rectangle at 0x19e164d8e10>,
#  <matplotlib.patches.Rectangle at 0x19e164d8f50>,
#  <matplotlib.patches.Rectangle at 0x19e164d9090>,
#  <matplotlib.patches.Rectangle at 0x19e164d91d0>,
#  <matplotlib.patches.Rectangle at 0x19e164d9310>,
#  <matplotlib.patches.Rectangle at 0x19e164d9450>,
#  <matplotlib.patches.Rectangle at 0x19e164d9590>,
#  <matplotlib.patches.Rectangle at 0x19e164d96d0>,
#  <matplotlib.patches.Rectangle at 0x19e164d9810>,
#  <matplotlib.patches.Rectangle at 0x19e164d9950>,
#  <matplotlib.patches.Rectangle at 0x19e164d9a90>,
#  <matplotlib.patches.Rectangle at 0x19e164d9bd0>,
#  <matplotlib.patches.Rectangle at 0x19e164d9d10>,
#  <matplotlib.patches.Rectangle at 0x19e164d9e50>,
#  <matplotlib.patches.Rectangle at 0x19e164d9f90>,
#  <matplotlib.patches.Rectangle at 0x19e164da0d0>,
#  <matplotlib.patches.Rectangle at 0x19e164da210>,
#  <matplotlib.patches.Rectangle at 0x19e164da350>,
#  <matplotlib.patches.Rectangle at 0x19e164da490>,
#  <matplotlib.patches.Rectangle at 0x19e164da5d0>,
#  <matplotlib.patches.Rectangle at 0x19e164da710>,
#  <matplotlib.patches.Rectangle at 0x19e164da850>,
#  <matplotlib.patches.Rectangle at 0x19e164da990>,
#  <matplotlib.patches.Rectangle at 0x19e164daad0>,
#  <matplotlib.patches.Rectangle at 0x19e164dac10>,
#  <matplotlib.patches.Rectangle at 0x19e164dad50>,
#  <matplotlib.patches.Rectangle at 0x19e164dae90>,
#  <matplotlib.patches.Rectangle at 0x19e164dafd0>,
#  <matplotlib.patches.Rectangle at 0x19e164db110>,
#  <matplotlib.patches.Rectangle at 0x19e164db250>,
#  <matplotlib.patches.Rectangle at 0x19e164db390>,
#  <matplotlib.patches.Rectangle at 0x19e164db4d0>,
#  <matplotlib.patches.Rectangle at 0x19e164db610>,
#  <matplotlib.patches.Rectangle at 0x19e164db750>,
#  <matplotlib.patches.Rectangle at 0x19e164db890>,
#  <matplotlib.patches.Rectangle at 0x19e164db9d0>,
#  <matplotlib.patches.Rectangle at 0x19e164dbb10>,
#  <matplotlib.patches.Rectangle at 0x19e164dbc50>,
#  <matplotlib.patches.Rectangle at 0x19e164dbd90>,
#  <matplotlib.patches.Rectangle at 0x19e164dbed0>,
#  <matplotlib.patches.Rectangle at 0x19e1653c050>,
#  <matplotlib.patches.Rectangle at 0x19e1653c190>,
#  <matplotlib.patches.Rectangle at 0x19e1653c2d0>,
#  <matplotlib.patches.Rectangle at 0x19e1653c410>,
#  <matplotlib.patches.Rectangle at 0x19e1653c550>,
#  <matplotlib.patches.Rectangle at 0x19e1653c690>,
#  <matplotlib.patches.Rectangle at 0x19e1653c7d0>,
#  <matplotlib.patches.Rectangle at 0x19e1653c910>,
#  <matplotlib.patches.Rectangle at 0x19e1653ca50>,
#  <matplotlib.patches.Rectangle at 0x19e1653cb90>,
#  <matplotlib.patches.Rectangle at 0x19e1653ccd0>,
#  <matplotlib.patches.Rectangle at 0x19e1653ce10>,
#  <matplotlib.patches.Rectangle at 0x19e1653cf50>,
#  <matplotlib.patches.Rectangle at 0x19e1653d090>,
#  <matplotlib.patches.Rectangle at 0x19e1653d1d0>,
#  <matplotlib.patches.Rectangle at 0x19e1653d310>,
#  <matplotlib.patches.Rectangle at 0x19e1653d450>,
#  <matplotlib.patches.Rectangle at 0x19e1653d590>,
#  <matplotlib.patches.Rectangle at 0x19e1653d6d0>,
#  <matplotlib.patches.Rectangle at 0x19e1653d810>,
#  <matplotlib.patches.Rectangle at 0x19e1653d950>,
#  <matplotlib.patches.Rectangle at 0x19e1653da90>,
#  <matplotlib.patches.Rectangle at 0x19e1653dbd0>,
#  <matplotlib.patches.Rectangle at 0x19e1653dd10>,
#  <matplotlib.patches.Rectangle at 0x19e1653de50>]

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=20,density=True)
r = out[2].get_children()[10]
r.set_color('r')

# %% [markdown]
# ---

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %%
data = np.random.normal(0,100,(5,5))
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('./Iris.csv').drop('Id',axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)   # دو به دو نسبت به خودش رسم میکنه

# %%
sns.pairplot(df,hue='Species')

# %%
sns.scatterplot(df,x='SepalLengthCm',y='PetalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
c = df['Species'].astype('category').cat.codes
c
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Length: 150, dtype: int8

# %%
c = df['Species'].astype('category').cat.codes     # code miad adad mikone
plt.scatter(df['SepalLengthCm'].values,df['PetalLengthCm'].values,c = c)

# %% [markdown]
# ---

# %%
plt.figure(figsize=(15,7),dpi=72)   #dpi yani be ezay har inch 72 ta noqte bekesh
# chap  300dpi

x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))
plt.plot(x,y)
plt.plot(x,y_2)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y_2,'b')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(2,1,1)
plt.plot(x,y,'r')
plt.subplot(2,1,2)
plt.plot(x,y_2,'b')

# %%
from PIL import Image
im  =np.array(Image.open('./1.jpg'))

# %%
plt.figure(figsize=(20, 7), dpi=72)

plt.subplot(1, 4, 1)
plt.imshow(im)
plt.title('RGB')

plt.subplot(1, 4, 2)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(1, 4, 3)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(1, 4, 4) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
plt.figure(figsize=(25, 7), dpi=72)

plt.subplot(2,3, 2)
plt.imshow(im)
plt.title('RGB')
plt.xticks([0,im.shape[1]])
plt.yticks([0,im.shape[0]])

plt.subplot(2,3, 4)


plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(2,3, 5)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(2,3, 6) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
x= np.linspace(1,360,100)
y = np.sin(np.radians(x))
y_2 = np.log(x)


plt.plot(x,y,'r')

plt.plot(x,y_2,'b')

# %%
x= np.linspace(1,360,100)
y = np.sin(np.radians(x))
y_2 = np.log(x)

fig,ax = plt.subplots()


ax.plot(x,y,'r')
ax.set_ylabel('$sin(x)$')
ax2 = ax.twinx() # کپی از نمودار با x مشترک
ax2.plot(x,y_2,'b')
ax2.set_ylabel('$log(x)$')
# Out:
# Text(0, 0.5, '$log(x)$')
