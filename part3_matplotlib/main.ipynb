# %%
import matplotlib.pyplot as plt

# %% [markdown]
# کد پایین یعنی نمودار داخل همین اجرا میشه و پنجره جدید باز نمیکنه

# %%
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [2, 3, 4, 6, 3, 2, 6, 7, 8]

# plt.plot(x, y,'*', color="green")
plt.plot(x, y,marker='*', color="green")
plt.title("plot")
plt.xlabel('tahaX')
plt.ylabel('tahay')
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.bar(x, y, color="red")
plt.title("bar")
plt.xlabel("color")
plt.ylabel("count")
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.pie(y, labels=x, autopct="%1.1f%%", colors=["red", "green", "blue", "orange"])
plt.title("example")

plt.show()

# %%
import numpy as np

x = np.random.rand(1000,1)

plt.hist(x,bins=5)
plt.show()

# %%
x = np.random.rand(64,64)
plt.imshow(x ,cmap=('hot'))
plt.colorbar()
plt.show()

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

# %%
plt.plot(x,y)

# %%
plt.plot(y)   # مقدار تولید میشه با کمک
            # Arange

# %%
plt.plot(x,y,'o-r')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.savefig('out.png')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.legend(['$Sin(x)$','Cos'])
plt.title('some plots')
plt.xlabel('values')
plt.ylabel('$Sin & Cos$')
plt.grid(which='both')
plt.xlim(0,360)
plt.ylim(-1,1)
plt.axis('on');

# %%
data = np.random.uniform(1,10,(100,2))
plt.plot(data[:,0],data[:,1])

# %%
data = np.random.uniform(1,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
data = np.random.normal(1,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
y = np.random.normal(1,10,(1000))
x = np.arange(1000)
plt.scatter(x,y ,marker='v',s=50,c='#c10099',alpha=0.5)

# plt.plot(x,np.full((1000,),0) ,'r')
plt.plot([0,1000],[0,0],'r')
plt.plot([0,1000],[10,10],'m--')
plt.plot([0,1000],[-10,-10],'m--')
plt.xlim((0,1000))
# Out:
# (0.0, 1000.0)

# %%
x = np.array([1, 5, 8, 12])
y = np.array([-2, -3, 5, 9])

plt.scatter(x, y, marker="o", s=[23, 156, 288, 399], c=["r", "b", "#FF0000", "y"])

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

plt.scatter(x,y ,c=['r','b']*25)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

# color map
# https://matplotlib.org/stable/users/explain/colors/colormaps.html


plt.scatter(x,y ,c=np.arange(50),cmap='plasma')

# %%
x= np.linspace(0,360,500)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(500),cmap='hsv')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(50),cmap='hsv',vmin=0,vmax=100)

# plt.xticks(np.arange(0,360,10),rotation=90)
# plt.xticks(np.arange(0,360,10),minor=True,rotation=90)
plt.xticks((0,360,10),('A','B','C'))
# Out:
# ([<matplotlib.axis.XTick at 0x13aef8eead0>,
#   <matplotlib.axis.XTick at 0x13aefa58f50>,
#   <matplotlib.axis.XTick at 0x13aefa596d0>],
#  [Text(0, 0, 'A'), Text(360, 0, 'B'), Text(10, 0, 'C')])

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
plt.bar(x,y,bottom=10)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
bottom = np.random.uniform(0,20,(10))

plt.bar(x,y,bottom=bottom)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
left = np.random.uniform(0,20,(10))

plt.barh(x,y,left=left)
# plt.xticks([1,2,3])
# Out:
# <BarContainer object of 10 artists>

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=200,density=True)
# density=True احتمال هر کدوم رو میگه
data
# Out:
# array([-68.49045368, 360.48821855,  -5.80945836, ...,   6.24537452,
#         43.8308148 , -38.23932451], shape=(10000,))

# %%
out[0] # تعداد داخل هر بین
# Out:
# array([5.39274288e-05, 2.69637144e-05, 5.39274288e-05, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5
#         124.84367254,  128.55236039,  132.26104824,  135.96973609,
#         139.67842394,  143.38711179,  147.09579963,  150.80448748,
#         154.51317533,  158.22186318,  161.93055103,  165.63923888,
#         169.34792673,  173.05661458,  176.76530243,  180.47399028,
#         184.18267813,  187.89136598,  191.60005382,  195.30874167,
#         199.01742952,  202.72611737,  206.43480522,  210.14349307,
#         213.85218092,  217.56086877,  221.26955662,  224.97824447,
#         228.68693232,  232.39562017,  236.10430801,  239.81299586,
#         243.52168371,  247.23037156,  250.93905941,  254.64774726,
#         258.35643511,  262.06512296,  265.77381081,  269.48249866,
#         273.19118651,  276.89987436,  280.6085622 ,  284.31725005,
#         288.0259379 ,  291.73462575,  295.4433136 ,  299.15200145,
#         302.8606893 ,  306.56937715,  310.278065  ,  313.98675285,
#         317.6954407 ,  321.40412855,  325.11281639,  328.82150424,
#         332.53019209,  336.23887994,  339.94756779,  343.65625564,
#         347.36494349,  351.07363134,  354.78231919,  358.49100704,
#         362.19969489,  365.90838274,  369.61707058,  373.32575843,
#         377.03444628,  380.74313413,  384.45182198,  388.16050983,
#         391.86919768])

# %%
out[2]
# Out:
# <BarContainer object of 200 artists>

# %%
out[2].get_children()  # میتونی تک تک اون کندل هارو بگیری
# Out:
# [<matplotlib.patches.Rectangle at 0x13aefaede50>,
#  <matplotlib.patches.Rectangle at 0x13aefaee490>,
#  <matplotlib.patches.Rectangle at 0x13aefaee350>,
#  <matplotlib.patches.Rectangle at 0x13aefaee210>,
#  <matplotlib.patches.Rectangle at 0x13aefaee0d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaedf90>,
#  <matplotlib.patches.Rectangle at 0x13aefaee5d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaeec10>,
#  <matplotlib.patches.Rectangle at 0x13aefaeead0>,
#  <matplotlib.patches.Rectangle at 0x13aefaee990>,
#  <matplotlib.patches.Rectangle at 0x13aefaee850>,
#  <matplotlib.patches.Rectangle at 0x13aefaee710>,
#  <matplotlib.patches.Rectangle at 0x13aefaeed50>,
#  <matplotlib.patches.Rectangle at 0x13aefaef390>,
#  <matplotlib.patches.Rectangle at 0x13aefaef250>,
#  <matplotlib.patches.Rectangle at 0x13aefaef110>,
#  <matplotlib.patches.Rectangle at 0x13aefaeefd0>,
#  <matplotlib.patches.Rectangle at 0x13aefaeee90>,
#  <matplotlib.patches.Rectangle at 0x13aefaef4d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaefb10>,
#  <matplotlib.patches.Rectangle at 0x13aefaef9d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaef890>,
#  <matplotlib.patches.Rectangle at 0x13aefaef750>,
#  <matplotlib.patches.Rectangle at 0x13aefaef610>,
#  <matplotlib.patches.Rectangle at 0x13aefaec050>,
#  <matplotlib.patches.Rectangle at 0x13aefaec690>,
#  <matplotlib.patches.Rectangle at 0x13aefaec550>,
#  <matplotlib.patches.Rectangle at 0x13aefaec410>,
#  <matplotlib.patches.Rectangle at 0x13aefaec2d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaec190>,
#  <matplotlib.patches.Rectangle at 0x13aefaec7d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaece10>,
#  <matplotlib.patches.Rectangle at 0x13aefaeca50>,
#  <matplotlib.patches.Rectangle at 0x13aefaed590>,
#  <matplotlib.patches.Rectangle at 0x13aefaed450>,
#  <matplotlib.patches.Rectangle at 0x13aefaed310>,
#  <matplotlib.patches.Rectangle at 0x13aefaed1d0>,
#  <matplotlib.patches.Rectangle at 0x13aefaed090>,
#  <matplotlib.patches.Rectangle at 0x13aef96c050>,
#  <matplotlib.patches.Rectangle at 0x13aef96c190>,
#  <matplotlib.patches.Rectangle at 0x13aefaecb90>,
#  <matplotlib.patches.Rectangle at 0x13aefaecf50>,
#  <matplotlib.patches.Rectangle at 0x13aefaec910>,
#  <matplotlib.patches.Rectangle at 0x13aefaeccd0>,
#  <matplotlib.patches.Rectangle at 0x13aef96c2d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96c410>,
#  <matplotlib.patches.Rectangle at 0x13aef96c550>,
#  <matplotlib.patches.Rectangle at 0x13aef96c690>,
#  <matplotlib.patches.Rectangle at 0x13aef96c7d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96c910>,
#  <matplotlib.patches.Rectangle at 0x13aef96ca50>,
#  <matplotlib.patches.Rectangle at 0x13aef96cb90>,
#  <matplotlib.patches.Rectangle at 0x13aef96ccd0>,
#  <matplotlib.patches.Rectangle at 0x13aef96ce10>,
#  <matplotlib.patches.Rectangle at 0x13aef96cf50>,
#  <matplotlib.patches.Rectangle at 0x13aef96d090>,
#  <matplotlib.patches.Rectangle at 0x13aef96d1d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96d310>,
#  <matplotlib.patches.Rectangle at 0x13aef96d450>,
#  <matplotlib.patches.Rectangle at 0x13aef96d590>,
#  <matplotlib.patches.Rectangle at 0x13aef96d6d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96d810>,
#  <matplotlib.patches.Rectangle at 0x13aef96d950>,
#  <matplotlib.patches.Rectangle at 0x13aef96da90>,
#  <matplotlib.patches.Rectangle at 0x13aef96dbd0>,
#  <matplotlib.patches.Rectangle at 0x13aef96dd10>,
#  <matplotlib.patches.Rectangle at 0x13aef96de50>,
#  <matplotlib.patches.Rectangle at 0x13aef96df90>,
#  <matplotlib.patches.Rectangle at 0x13aef96e0d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96e210>,
#  <matplotlib.patches.Rectangle at 0x13aef96e350>,
#  <matplotlib.patches.Rectangle at 0x13aef96e490>,
#  <matplotlib.patches.Rectangle at 0x13aef96e5d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96e710>,
#  <matplotlib.patches.Rectangle at 0x13aef96e850>,
#  <matplotlib.patches.Rectangle at 0x13aef96e990>,
#  <matplotlib.patches.Rectangle at 0x13aef96ead0>,
#  <matplotlib.patches.Rectangle at 0x13aef96ec10>,
#  <matplotlib.patches.Rectangle at 0x13aef96ed50>,
#  <matplotlib.patches.Rectangle at 0x13aef96ee90>,
#  <matplotlib.patches.Rectangle at 0x13aef96efd0>,
#  <matplotlib.patches.Rectangle at 0x13aef96f110>,
#  <matplotlib.patches.Rectangle at 0x13aef96f250>,
#  <matplotlib.patches.Rectangle at 0x13aef96f390>,
#  <matplotlib.patches.Rectangle at 0x13aef96f4d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96f610>,
#  <matplotlib.patches.Rectangle at 0x13aef96f750>,
#  <matplotlib.patches.Rectangle at 0x13aef96f890>,
#  <matplotlib.patches.Rectangle at 0x13aef96f9d0>,
#  <matplotlib.patches.Rectangle at 0x13aef96fb10>,
#  <matplotlib.patches.Rectangle at 0x13aef96fc50>,
#  <matplotlib.patches.Rectangle at 0x13aef96fd90>,
#  <matplotlib.patches.Rectangle at 0x13aef96fed0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0050>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0190>,
#  <matplotlib.patches.Rectangle at 0x13aef9d02d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0410>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0550>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0690>,
#  <matplotlib.patches.Rectangle at 0x13aef9d07d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0910>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0a50>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0b90>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0cd0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0e10>,
#  <matplotlib.patches.Rectangle at 0x13aef9d0f50>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1090>,
#  <matplotlib.patches.Rectangle at 0x13aef9d11d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1310>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1450>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1590>,
#  <matplotlib.patches.Rectangle at 0x13aef9d16d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1810>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1950>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1a90>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1bd0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1d10>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1e50>,
#  <matplotlib.patches.Rectangle at 0x13aef9d1f90>,
#  <matplotlib.patches.Rectangle at 0x13aef9d20d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2210>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2350>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2490>,
#  <matplotlib.patches.Rectangle at 0x13aef9d25d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2710>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2850>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2990>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2ad0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2c10>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2d50>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2e90>,
#  <matplotlib.patches.Rectangle at 0x13aef9d2fd0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3110>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3250>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3390>,
#  <matplotlib.patches.Rectangle at 0x13aef9d34d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3610>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3750>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3890>,
#  <matplotlib.patches.Rectangle at 0x13aef9d39d0>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3b10>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3c50>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3d90>,
#  <matplotlib.patches.Rectangle at 0x13aef9d3ed0>,
#  <matplotlib.patches.Rectangle at 0x13af0b44050>,
#  <matplotlib.patches.Rectangle at 0x13af0b44190>,
#  <matplotlib.patches.Rectangle at 0x13af0b442d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b44410>,
#  <matplotlib.patches.Rectangle at 0x13af0b44550>,
#  <matplotlib.patches.Rectangle at 0x13af0b44690>,
#  <matplotlib.patches.Rectangle at 0x13af0b447d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b44910>,
#  <matplotlib.patches.Rectangle at 0x13af0b44a50>,
#  <matplotlib.patches.Rectangle at 0x13af0b44b90>,
#  <matplotlib.patches.Rectangle at 0x13af0b44cd0>,
#  <matplotlib.patches.Rectangle at 0x13af0b44e10>,
#  <matplotlib.patches.Rectangle at 0x13af0b44f50>,
#  <matplotlib.patches.Rectangle at 0x13af0b45090>,
#  <matplotlib.patches.Rectangle at 0x13af0b451d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b45310>,
#  <matplotlib.patches.Rectangle at 0x13af0b45450>,
#  <matplotlib.patches.Rectangle at 0x13af0b45590>,
#  <matplotlib.patches.Rectangle at 0x13af0b456d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b45810>,
#  <matplotlib.patches.Rectangle at 0x13af0b45950>,
#  <matplotlib.patches.Rectangle at 0x13af0b45a90>,
#  <matplotlib.patches.Rectangle at 0x13af0b45bd0>,
#  <matplotlib.patches.Rectangle at 0x13af0b45d10>,
#  <matplotlib.patches.Rectangle at 0x13af0b45e50>,
#  <matplotlib.patches.Rectangle at 0x13af0b45f90>,
#  <matplotlib.patches.Rectangle at 0x13af0b460d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b46210>,
#  <matplotlib.patches.Rectangle at 0x13af0b46350>,
#  <matplotlib.patches.Rectangle at 0x13af0b46490>,
#  <matplotlib.patches.Rectangle at 0x13af0b465d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b46710>,
#  <matplotlib.patches.Rectangle at 0x13af0b46850>,
#  <matplotlib.patches.Rectangle at 0x13af0b46990>,
#  <matplotlib.patches.Rectangle at 0x13af0b46ad0>,
#  <matplotlib.patches.Rectangle at 0x13af0b46c10>,
#  <matplotlib.patches.Rectangle at 0x13af0b46d50>,
#  <matplotlib.patches.Rectangle at 0x13af0b46e90>,
#  <matplotlib.patches.Rectangle at 0x13af0b46fd0>,
#  <matplotlib.patches.Rectangle at 0x13af0b47110>,
#  <matplotlib.patches.Rectangle at 0x13af0b47250>,
#  <matplotlib.patches.Rectangle at 0x13af0b47390>,
#  <matplotlib.patches.Rectangle at 0x13af0b474d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b47610>,
#  <matplotlib.patches.Rectangle at 0x13af0b47750>,
#  <matplotlib.patches.Rectangle at 0x13af0b47890>,
#  <matplotlib.patches.Rectangle at 0x13af0b479d0>,
#  <matplotlib.patches.Rectangle at 0x13af0b47b10>,
#  <matplotlib.patches.Rectangle at 0x13af0b47c50>,
#  <matplotlib.patches.Rectangle at 0x13af0b47d90>,
#  <matplotlib.patches.Rectangle at 0x13af0b47ed0>,
#  <matplotlib.patches.Rectangle at 0x13af0ba4050>,
#  <matplotlib.patches.Rectangle at 0x13af0ba4190>,
#  <matplotlib.patches.Rectangle at 0x13af0ba42d0>,
#  <matplotlib.patches.Rectangle at 0x13af0ba4410>,
#  <matplotlib.patches.Rectangle at 0x13af0ba4550>]

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=20,density=True)
r = out[2].get_children()[10]
r.set_color('r')

# %% [markdown]
# ---

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %%
data = np.random.normal(0,100,(5,5))
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('./Iris.csv').drop('Id',axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)   # دو به دو نسبت به خودش رسم میکنه

# %%
sns.pairplot(df,hue='Species')

# %%
sns.scatterplot(df,x='SepalLengthCm',y='PetalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
c = df['Species'].astype('category')
c
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: category
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
c = df['Species'].astype('category').cat.codes     # code miad adad mikone
plt.scatter(df['SepalLengthCm'].values,df['PetalLengthCm'].values,c = c)

# %% [markdown]
# ---

# %%
plt.figure(figsize=(15,7),dpi=72)   #dpi yani be ezay har inch 20 ta noqte bekesh
# chap adi 300

x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))
plt.plot(x,y)
plt.plot(x,y_2)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y_2,'b')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(2,1,1)
plt.plot(x,y,'r')
plt.subplot(2,1,2)
plt.plot(x,y_2,'b')

# %%
from PIL import Image
im  =np.array(Image.open('./1.jpg'))

# %%
plt.figure(figsize=(20, 7), dpi=72)

plt.subplot(1, 4, 1)
plt.imshow(im)
plt.title('RGB')

plt.subplot(1, 4, 2)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(1, 4, 3)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(1, 4, 4) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
plt.figure(figsize=(20, 7), dpi=72)

plt.subplot(2,3, 2)
plt.imshow(im)
plt.title('RGB')

plt.subplot(2,3, 4)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(2,3, 5)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(2,3, 6) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')
