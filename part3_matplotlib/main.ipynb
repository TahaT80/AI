# %%
import matplotlib.pyplot as plt

# %% [markdown]
# کد پایین یعنی نمودار داخل همین اجرا میشه و پنجره جدید باز نمیکنه

# %%
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [2, 3, 4, 6, 3, 2, 6, 7, 8]

# plt.plot(x, y,'*', color="green")
plt.plot(x, y,marker='*', color="green")
plt.title("plot")
plt.xlabel('tahaX')
plt.ylabel('tahay')
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.bar(x, y, color="red")
plt.title("bar")
plt.xlabel("color")
plt.ylabel("count")
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.pie(y, labels=x, autopct="%1.1f%%", colors=["red", "green", "blue", "orange"])
plt.title("example")

plt.show()

# %%
import numpy as np

x = np.random.rand(1000,1)

plt.hist(x,bins=5)
plt.show()

# %%
x = np.random.rand(64,64)
plt.imshow(x ,cmap=('hot'))
plt.colorbar()
plt.show()

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

# %%
plt.plot(x,y)

# %%
plt.plot(y)   # مقدار تولید میشه با کمک
            # Arange

# %%
plt.plot(x,y,'o-r')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.savefig('out.png')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.legend(['$Sin(x)$','Cos'])
plt.title('some plots')
plt.xlabel('values')
plt.ylabel('$Sin & Cos$')
plt.grid(which='both')
plt.xlim(0,360)
plt.ylim(-1,1)
plt.axis('on');

# %%
data = np.random.uniform(1,10,(100,2))
plt.plot(data[:,0],data[:,1])

# %%
data = np.random.uniform(1,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
data = np.random.normal(0,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
y = np.random.normal(0,10,(1000))
x = np.arange(1000)
plt.scatter(x,y ,marker='v',s=50,c='#c10099',alpha=0.5)

# plt.plot(x,np.full((1000,),0) ,'r')
plt.plot([0,1000],[0,0],'r')
plt.plot([0,1000],[10,10],'m--')
plt.plot([0,1000],[-10,-10],'m--')
plt.xlim((0,1000))
# Out:
# (0.0, 1000.0)

# %%
x = np.array([1, 5, 8, 12])
y = np.array([-2, -3, 5, 9])

plt.scatter(x, y, marker="o", s=[23, 156, 288, 399], c=["r", "b", "#FF0000", "y"])

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

plt.scatter(x,y ,c=['r','b']*25)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

# color map
# https://matplotlib.org/stable/users/explain/colors/colormaps.html


plt.scatter(x,y ,c=np.arange(50),cmap='plasma')

# %%
x= np.linspace(0,360,500)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(500),cmap='hsv')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(50),cmap='hsv',vmin=0,vmax=100)

# plt.xticks(np.arange(0,360,10),rotation=90)
# plt.xticks(np.arange(0,360,10),minor=True,rotation=90)
plt.xticks((0,360,10),('A','B','C'))
# Out:
# ([<matplotlib.axis.XTick at 0x20e74393c50>,
#   <matplotlib.axis.XTick at 0x20e743c20d0>,
#   <matplotlib.axis.XTick at 0x20e743c2850>],
#  [Text(0, 0, 'A'), Text(360, 0, 'B'), Text(10, 0, 'C')])

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
plt.bar(x,y,bottom=10)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
bottom = np.random.uniform(0,20,(10))

plt.bar(x,y,bottom=bottom)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
left = np.random.uniform(0,20,(10))

plt.barh(x,y,left=left)
# plt.xticks([1,2,3])
# Out:
# <BarContainer object of 10 artists>

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=200)
data
# Out:
# array([-207.38745714,   99.82542793,   30.9834572 , ...,  -49.22545414,
#         -64.66070667,  -85.09914186], shape=(10000,))

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=200,density=True)
# density=True احتمال هر کدوم رو میگه
data
# Out:
# array([  35.99025803,  -82.65876318,   58.22763664, ...,   97.92290812,
#         -83.6765251 , -115.08596829], shape=(10000,))

# %%
out[0] # تعداد داخل هر بین
# Out:
# 200

# %%
out[1] # عدد هر بین
# Out:
# array([-383.75859368, -379.98903528, -376.21947689, -372.4499185 ,
#        -368.68036011, -364.91080172, -361.14124333, -357.37168494,
#        -353.60212655, -349.83256816, -346.06300977, -342.29345138,
#        -338.52389299, -334.7543346 , -330.98477621, -327.21521782,
#        -323.44565942, -319.67610103, -315.90654264, -312.13698425,
#        -308.36742586, -304.59786747, -300.82830908, -297.05875069,
#        -293.2891923 , -289.51963391, -285.75007552, -281.98051713,
#        -278.21095874, -274.44140035, -270.67184196, -266.90228356,
#        -263.13272517, -259.36316678, -255.59360839, -251.82405   ,
#        -248.05449161, -244.28493322, -240.51537483, -236.74581644,
#        -232.97625805, -229.20669966, -225.43714127, -221.66758288,
#        -217.89802449, -214.1284661 , -210.3589077 , -206.58934931,
#        -202.81979092, -199.05023253, -195.28067414, -191.51111575,
#        -187.74155736, -183.97199897, -180.20244058, -176.43288219,
#        -172.6633238 , -168.89376541, -165.12420702, -161.35464863,
#        -157.58509024, -153.81553185, -150.04597345, -146.27641506,
#        -142.50685667, -138.73729828, -134.96773989, -131.1981815 ,
#        -127.42862311, -123.65906472, -119.88950633, -116.11994794,
#        -112.35038955, -108.58083116, -104.81127277, -101.04171438,
#         -97.27215599,  -93.50259759,  -89.7330392 ,  -85.96348081,
#         -82.19392242,  -78.42436403,  -74.65480564,  -70.88524725,
#         -67.11568886,  -63.34613047,  -59.57657208,  -55.80701369,
#         -52.0374553 ,  -48.26789691,  -44.49833852,  -40.72878013,
#         -36.95922173,  -33.18966334,  -29.42010495,  -25.65054656,
#         -21.88098817,  -18.11142978,  -14.34187139,  -10.572313  ,
#          -6.80275461,   -3.03319622,    0.73636217,    4.50592056,
#           8.27547895,   12.04503734,   15.81459573,   19.58415413,
#          23.35371252,   27.12327091,   30.8928293 ,   34.66238769,
#          38.43194608,   42.20150447,   45.97106286,   49.74062125,
#          53.51017964,   57.27973803,   61.04929642,   64.81885481,
#          68.5884132 ,   72.35797159,   76.12752999,   79.89708838,
#          83.66664677,   87.43620516,   91.20576355,   94.97532194,
#          98.74488033,  102.51443872,  106.28399711,  110.0535555 ,
#         113.82311389,  117.59267228,  121.36223067,  125.13178906,
#         128.90134745,  132.67090585,  136.44046424,  140.21002263,
#         143.97958102,  147.74913941,  151.5186978 ,  155.28825619,
#         159.05781458,  162.82737297,  166.59693136,  170.36648975,
#         174.13604814,  177.90560653,  181.67516492,  185.44472331,
#         189.21428171,  192.9838401 ,  196.75339849,  200.52295688,
#         204.29251527,  208.06207366,  211.83163205,  215.60119044,
#         219.37074883,  223.14030722,  226.90986561,  230.679424  ,
#         234.44898239,  238.21854078,  241.98809917,  245.75765757,
#         249.52721596,  253.29677435,  257.06633274,  260.83589113,
#         264.60544952,  268.37500791,  272.1445663 ,  275.91412469,
#         279.68368308,  283.45324147,  287.22279986,  290.99235825,
#         294.76191664,  298.53147503,  302.30103342,  306.07059182,
#         309.84015021,  313.6097086 ,  317.37926699,  321.14882538,
#         324.91838377,  328.68794216,  332.45750055,  336.22705894,
#         339.99661733,  343.76617572,  347.53573411,  351.3052925 ,
#         355.07485089,  358.84440928,  362.61396768,  366.38352607,
#         370.15308446])

# %%
out[2]
# Out:
# <BarContainer object of 200 artists>

# %%
out[2].get_children()  # میتونی تک تک اون کندل هارو بگیری
# Out:
# [<matplotlib.patches.Rectangle at 0x20e73e182d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e18410>,
#  <matplotlib.patches.Rectangle at 0x20e73e18550>,
#  <matplotlib.patches.Rectangle at 0x20e73e18690>,
#  <matplotlib.patches.Rectangle at 0x20e73e187d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e18910>,
#  <matplotlib.patches.Rectangle at 0x20e73e18a50>,
#  <matplotlib.patches.Rectangle at 0x20e73e18b90>,
#  <matplotlib.patches.Rectangle at 0x20e73e18cd0>,
#  <matplotlib.patches.Rectangle at 0x20e73e18e10>,
#  <matplotlib.patches.Rectangle at 0x20e73e18f50>,
#  <matplotlib.patches.Rectangle at 0x20e73e19090>,
#  <matplotlib.patches.Rectangle at 0x20e73e191d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e19310>,
#  <matplotlib.patches.Rectangle at 0x20e73e19450>,
#  <matplotlib.patches.Rectangle at 0x20e73e19590>,
#  <matplotlib.patches.Rectangle at 0x20e73e196d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e19810>,
#  <matplotlib.patches.Rectangle at 0x20e73e19950>,
#  <matplotlib.patches.Rectangle at 0x20e73e19a90>,
#  <matplotlib.patches.Rectangle at 0x20e73e19bd0>,
#  <matplotlib.patches.Rectangle at 0x20e73e19d10>,
#  <matplotlib.patches.Rectangle at 0x20e73e19e50>,
#  <matplotlib.patches.Rectangle at 0x20e73e19f90>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a0d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a210>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a350>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a490>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a5d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a710>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a850>,
#  <matplotlib.patches.Rectangle at 0x20e73e1a990>,
#  <matplotlib.patches.Rectangle at 0x20e73e1ad50>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b110>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b250>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b390>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b4d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b610>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b750>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b890>,
#  <matplotlib.patches.Rectangle at 0x20e73e1ac10>,
#  <matplotlib.patches.Rectangle at 0x20e73e1afd0>,
#  <matplotlib.patches.Rectangle at 0x20e73e1ae90>,
#  <matplotlib.patches.Rectangle at 0x20e73e1aad0>,
#  <matplotlib.patches.Rectangle at 0x20e73e1b9d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e1bb10>,
#  <matplotlib.patches.Rectangle at 0x20e73e1bc50>,
#  <matplotlib.patches.Rectangle at 0x20e73e1bd90>,
#  <matplotlib.patches.Rectangle at 0x20e73e1bed0>,
#  <matplotlib.patches.Rectangle at 0x20e73e84050>,
#  <matplotlib.patches.Rectangle at 0x20e73e84190>,
#  <matplotlib.patches.Rectangle at 0x20e73e842d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e84410>,
#  <matplotlib.patches.Rectangle at 0x20e73e84550>,
#  <matplotlib.patches.Rectangle at 0x20e73e84690>,
#  <matplotlib.patches.Rectangle at 0x20e73e847d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e84910>,
#  <matplotlib.patches.Rectangle at 0x20e73e84a50>,
#  <matplotlib.patches.Rectangle at 0x20e73e84b90>,
#  <matplotlib.patches.Rectangle at 0x20e73e84cd0>,
#  <matplotlib.patches.Rectangle at 0x20e73e84e10>,
#  <matplotlib.patches.Rectangle at 0x20e73e84f50>,
#  <matplotlib.patches.Rectangle at 0x20e73e85090>,
#  <matplotlib.patches.Rectangle at 0x20e73e851d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e85310>,
#  <matplotlib.patches.Rectangle at 0x20e73e85450>,
#  <matplotlib.patches.Rectangle at 0x20e73e85590>,
#  <matplotlib.patches.Rectangle at 0x20e73e856d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e85810>,
#  <matplotlib.patches.Rectangle at 0x20e73e85950>,
#  <matplotlib.patches.Rectangle at 0x20e73e85a90>,
#  <matplotlib.patches.Rectangle at 0x20e73e85bd0>,
#  <matplotlib.patches.Rectangle at 0x20e73e85d10>,
#  <matplotlib.patches.Rectangle at 0x20e73e85e50>,
#  <matplotlib.patches.Rectangle at 0x20e73e85f90>,
#  <matplotlib.patches.Rectangle at 0x20e73e860d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e86210>,
#  <matplotlib.patches.Rectangle at 0x20e73e86350>,
#  <matplotlib.patches.Rectangle at 0x20e73e86490>,
#  <matplotlib.patches.Rectangle at 0x20e73e865d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e86710>,
#  <matplotlib.patches.Rectangle at 0x20e73e86850>,
#  <matplotlib.patches.Rectangle at 0x20e73e86990>,
#  <matplotlib.patches.Rectangle at 0x20e73e86ad0>,
#  <matplotlib.patches.Rectangle at 0x20e73e86c10>,
#  <matplotlib.patches.Rectangle at 0x20e73e86d50>,
#  <matplotlib.patches.Rectangle at 0x20e73e86e90>,
#  <matplotlib.patches.Rectangle at 0x20e73e86fd0>,
#  <matplotlib.patches.Rectangle at 0x20e73e87110>,
#  <matplotlib.patches.Rectangle at 0x20e73e87250>,
#  <matplotlib.patches.Rectangle at 0x20e73e87390>,
#  <matplotlib.patches.Rectangle at 0x20e73e874d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e87610>,
#  <matplotlib.patches.Rectangle at 0x20e73e87750>,
#  <matplotlib.patches.Rectangle at 0x20e73e87890>,
#  <matplotlib.patches.Rectangle at 0x20e73e879d0>,
#  <matplotlib.patches.Rectangle at 0x20e73e87b10>,
#  <matplotlib.patches.Rectangle at 0x20e73e87c50>,
#  <matplotlib.patches.Rectangle at 0x20e73e87d90>,
#  <matplotlib.patches.Rectangle at 0x20e73e87ed0>,
#  <matplotlib.patches.Rectangle at 0x20e7578c050>,
#  <matplotlib.patches.Rectangle at 0x20e7578c190>,
#  <matplotlib.patches.Rectangle at 0x20e7578c2d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578c410>,
#  <matplotlib.patches.Rectangle at 0x20e7578c550>,
#  <matplotlib.patches.Rectangle at 0x20e7578c690>,
#  <matplotlib.patches.Rectangle at 0x20e7578c7d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578c910>,
#  <matplotlib.patches.Rectangle at 0x20e7578ca50>,
#  <matplotlib.patches.Rectangle at 0x20e7578cb90>,
#  <matplotlib.patches.Rectangle at 0x20e7578ccd0>,
#  <matplotlib.patches.Rectangle at 0x20e7578ce10>,
#  <matplotlib.patches.Rectangle at 0x20e7578cf50>,
#  <matplotlib.patches.Rectangle at 0x20e7578d090>,
#  <matplotlib.patches.Rectangle at 0x20e7578d1d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578d310>,
#  <matplotlib.patches.Rectangle at 0x20e7578d450>,
#  <matplotlib.patches.Rectangle at 0x20e7578d590>,
#  <matplotlib.patches.Rectangle at 0x20e7578d6d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578d810>,
#  <matplotlib.patches.Rectangle at 0x20e7578d950>,
#  <matplotlib.patches.Rectangle at 0x20e7578da90>,
#  <matplotlib.patches.Rectangle at 0x20e7578dbd0>,
#  <matplotlib.patches.Rectangle at 0x20e7578dd10>,
#  <matplotlib.patches.Rectangle at 0x20e7578de50>,
#  <matplotlib.patches.Rectangle at 0x20e7578df90>,
#  <matplotlib.patches.Rectangle at 0x20e7578e0d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578e210>,
#  <matplotlib.patches.Rectangle at 0x20e7578e350>,
#  <matplotlib.patches.Rectangle at 0x20e7578e490>,
#  <matplotlib.patches.Rectangle at 0x20e7578e5d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578e710>,
#  <matplotlib.patches.Rectangle at 0x20e7578e850>,
#  <matplotlib.patches.Rectangle at 0x20e7578e990>,
#  <matplotlib.patches.Rectangle at 0x20e7578ead0>,
#  <matplotlib.patches.Rectangle at 0x20e7578ec10>,
#  <matplotlib.patches.Rectangle at 0x20e7578ed50>,
#  <matplotlib.patches.Rectangle at 0x20e7578ee90>,
#  <matplotlib.patches.Rectangle at 0x20e7578efd0>,
#  <matplotlib.patches.Rectangle at 0x20e7578f110>,
#  <matplotlib.patches.Rectangle at 0x20e7578f250>,
#  <matplotlib.patches.Rectangle at 0x20e7578f390>,
#  <matplotlib.patches.Rectangle at 0x20e7578f4d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578f610>,
#  <matplotlib.patches.Rectangle at 0x20e7578f750>,
#  <matplotlib.patches.Rectangle at 0x20e7578f890>,
#  <matplotlib.patches.Rectangle at 0x20e7578f9d0>,
#  <matplotlib.patches.Rectangle at 0x20e7578fb10>,
#  <matplotlib.patches.Rectangle at 0x20e7578fc50>,
#  <matplotlib.patches.Rectangle at 0x20e7578fd90>,
#  <matplotlib.patches.Rectangle at 0x20e7578fed0>,
#  <matplotlib.patches.Rectangle at 0x20e757e4050>,
#  <matplotlib.patches.Rectangle at 0x20e757e4190>,
#  <matplotlib.patches.Rectangle at 0x20e757e42d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e4410>,
#  <matplotlib.patches.Rectangle at 0x20e757e4550>,
#  <matplotlib.patches.Rectangle at 0x20e757e4690>,
#  <matplotlib.patches.Rectangle at 0x20e757e47d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e4910>,
#  <matplotlib.patches.Rectangle at 0x20e757e4a50>,
#  <matplotlib.patches.Rectangle at 0x20e757e4b90>,
#  <matplotlib.patches.Rectangle at 0x20e757e4cd0>,
#  <matplotlib.patches.Rectangle at 0x20e757e4e10>,
#  <matplotlib.patches.Rectangle at 0x20e757e4f50>,
#  <matplotlib.patches.Rectangle at 0x20e757e5090>,
#  <matplotlib.patches.Rectangle at 0x20e757e51d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e5310>,
#  <matplotlib.patches.Rectangle at 0x20e757e5450>,
#  <matplotlib.patches.Rectangle at 0x20e757e5590>,
#  <matplotlib.patches.Rectangle at 0x20e757e56d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e5810>,
#  <matplotlib.patches.Rectangle at 0x20e757e5950>,
#  <matplotlib.patches.Rectangle at 0x20e757e5a90>,
#  <matplotlib.patches.Rectangle at 0x20e757e5bd0>,
#  <matplotlib.patches.Rectangle at 0x20e757e5d10>,
#  <matplotlib.patches.Rectangle at 0x20e757e5e50>,
#  <matplotlib.patches.Rectangle at 0x20e757e5f90>,
#  <matplotlib.patches.Rectangle at 0x20e757e60d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e6210>,
#  <matplotlib.patches.Rectangle at 0x20e757e6350>,
#  <matplotlib.patches.Rectangle at 0x20e757e6490>,
#  <matplotlib.patches.Rectangle at 0x20e757e65d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e6710>,
#  <matplotlib.patches.Rectangle at 0x20e757e6850>,
#  <matplotlib.patches.Rectangle at 0x20e757e6990>,
#  <matplotlib.patches.Rectangle at 0x20e757e6ad0>,
#  <matplotlib.patches.Rectangle at 0x20e757e6c10>,
#  <matplotlib.patches.Rectangle at 0x20e757e6d50>,
#  <matplotlib.patches.Rectangle at 0x20e757e6e90>,
#  <matplotlib.patches.Rectangle at 0x20e757e6fd0>,
#  <matplotlib.patches.Rectangle at 0x20e757e7110>,
#  <matplotlib.patches.Rectangle at 0x20e757e7250>,
#  <matplotlib.patches.Rectangle at 0x20e757e7390>,
#  <matplotlib.patches.Rectangle at 0x20e757e74d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e7610>,
#  <matplotlib.patches.Rectangle at 0x20e757e7750>,
#  <matplotlib.patches.Rectangle at 0x20e757e7890>,
#  <matplotlib.patches.Rectangle at 0x20e757e79d0>,
#  <matplotlib.patches.Rectangle at 0x20e757e7b10>,
#  <matplotlib.patches.Rectangle at 0x20e757e7c50>]

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=20,density=True)
r = out[2].get_children()[10]
r.set_color('r')

# %% [markdown]
# ---

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %%
data = np.random.normal(0,100,(5,5))
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('./Iris.csv').drop('Id',axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)   # دو به دو نسبت به خودش رسم میکنه

# %%
sns.pairplot(df,hue='Species')

# %%
sns.scatterplot(df,x='SepalLengthCm',y='PetalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
c = df['Species'].astype('category').cat.codes
c
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Length: 150, dtype: int8

# %%
c = df['Species'].astype('category').cat.codes     # code miad adad mikone
plt.scatter(df['SepalLengthCm'].values,df['PetalLengthCm'].values,c = c)

# %% [markdown]
# ---

# %%
plt.figure(figsize=(15,7),dpi=72)   #dpi yani be ezay har inch 20 ta noqte bekesh
# chap adi 300

x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))
plt.plot(x,y)
plt.plot(x,y_2)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y_2,'b')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(2,1,1)
plt.plot(x,y,'r')
plt.subplot(2,1,2)
plt.plot(x,y_2,'b')

# %%
from PIL import Image
im  =np.array(Image.open('./1.jpg'))

# %%
plt.figure(figsize=(20, 7), dpi=72)

plt.subplot(1, 4, 1)
plt.imshow(im)
plt.title('RGB')

plt.subplot(1, 4, 2)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(1, 4, 3)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(1, 4, 4) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
plt.figure(figsize=(25, 7), dpi=72)

plt.subplot(2,3, 2)
plt.imshow(im)
plt.title('RGB')
plt.xticks([0,im.shape[1]])
plt.yticks([0,im.shape[0]])

plt.subplot(2,3, 4)


plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(2,3, 5)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(2,3, 6) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
x= np.linspace(1,360,100)
y = np.sin(np.radians(x))
y_2 = np.log(x)


plt.plot(x,y,'r')

plt.plot(x,y_2,'b')

# %%
x= np.linspace(1,360,100)
y = np.sin(np.radians(x))
y_2 = np.log(x)

fig,ax = plt.subplots()


ax.plot(x,y,'r')
ax.set_ylabel('$sin(x)$')
ax2 = ax.twinx() # کپی از نمودار با x مشترک
ax2.plot(x,y_2,'b')
ax2.set_ylabel('$log(x)$')
# Out:
# Text(0, 0.5, '$log(x)$')
