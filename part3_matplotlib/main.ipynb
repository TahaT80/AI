# %%
import matplotlib.pyplot as plt

# %% [markdown]
# کد پایین یعنی نمودار داخل همین اجرا میشه و پنجره جدید باز نمیکنه

# %%
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [2, 3, 4, 6, 3, 2, 6, 7, 8]

# plt.plot(x, y,'*', color="green")
plt.plot(x, y,marker='*', color="green")
plt.title("plot")
plt.xlabel('tahaX')
plt.ylabel('tahay')
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.bar(x, y, color="red")
plt.title("bar")
plt.xlabel("color")
plt.ylabel("count")
plt.show()

# %%
x = ["red", "green", "blue", "orange"]
y = [4, 6, 2, 8]
plt.pie(y, labels=x, autopct="%1.1f%%", colors=["red", "green", "blue", "orange"])
plt.title("example")

plt.show()

# %%
import numpy as np

x = np.random.rand(1000,1)

plt.hist(x,bins=5)
plt.show()

# %%
x = np.random.rand(64,64)
plt.imshow(x ,cmap=('hot'))
plt.colorbar()
plt.show()

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

# %%
plt.plot(x,y)

# %%
plt.plot(y)   # مقدار تولید میشه با کمک
            # Arange

# %%
plt.plot(x,y,'o-r')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.savefig('out.png')

# %%
plt.plot(x,y)
plt.plot(x,y_2)
plt.legend(['$Sin(x)$','Cos'])
plt.title('some plots')
plt.xlabel('values')
plt.ylabel('$Sin & Cos$')
plt.grid(which='both')
plt.xlim(0,360)
plt.ylim(-1,1)
plt.axis('on');

# %%
data = np.random.uniform(1,10,(100,2))
plt.plot(data[:,0],data[:,1])

# %%
data = np.random.uniform(1,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
data = np.random.normal(1,10,(1000,2))

plt.scatter(data[:,0],data[:,1])

# %%
y = np.random.normal(1,10,(1000))
x = np.arange(1000)
plt.scatter(x,y ,marker='v',s=50,c='#c10099',alpha=0.5)

# plt.plot(x,np.full((1000,),0) ,'r')
plt.plot([0,1000],[0,0],'r')
plt.plot([0,1000],[10,10],'m--')
plt.plot([0,1000],[-10,-10],'m--')
plt.xlim((0,1000))
# Out:
# (0.0, 1000.0)

# %%
x = np.array([1, 5, 8, 12])
y = np.array([-2, -3, 5, 9])

plt.scatter(x, y, marker="o", s=[23, 156, 288, 399], c=["r", "b", "#FF0000", "y"])

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

plt.scatter(x,y ,c=['r','b']*25)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))

# color map
# https://matplotlib.org/stable/users/explain/colors/colormaps.html


plt.scatter(x,y ,c=np.arange(50),cmap='plasma')

# %%
x= np.linspace(0,360,500)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(500),cmap='hsv')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))


plt.scatter(x,y ,c=np.arange(50),cmap='hsv',vmin=0,vmax=100)

# plt.xticks(np.arange(0,360,10),rotation=90)
# plt.xticks(np.arange(0,360,10),minor=True,rotation=90)
plt.xticks((0,360,10),('A','B','C'))
# Out:
# ([<matplotlib.axis.XTick at 0x20e63fe8410>,
#   <matplotlib.axis.XTick at 0x20e63fea850>,
#   <matplotlib.axis.XTick at 0x20e63feafd0>],
#  [Text(0, 0, 'A'), Text(360, 0, 'B'), Text(10, 0, 'C')])

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
plt.bar(x,y,bottom=10)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
bottom = np.random.uniform(0,20,(10))

plt.bar(x,y,bottom=bottom)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
x = np.arange(0,10)
y = np.random.uniform(40,60,(10))
left = np.random.uniform(0,20,(10))

plt.barh(x,y,left=left)
# plt.xticks([1,2,3])
# Out:
# <BarContainer object of 10 artists>

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins
#         200.9852025 ,  205.06637311,  209.14754372,  213.22871433,
#         217.30988494,  221.39105555,  225.47222615,  229.55339676,
#         233.63456737,  237.71573798,  241.79690859,  245.8780792 ,
#         249.95924981,  254.04042042,  258.12159103,  262.20276164,
#         266.28393224,  270.36510285,  274.44627346,  278.52744407,
#         282.60861468,  286.68978529,  290.7709559 ,  294.85212651,
#         298.93329712,  303.01446772,  307.09563833,  311.17680894,
#         315.25797955,  319.33915016,  323.42032077,  327.50149138,
#         331.58266199,  335.6638326 ,  339.74500321,  343.82617381,
#         347.90734442,  351.98851503,  356.06968564,  360.15085625,
#         364.23202686,  368.31319747,  372.39436808,  376.47553869,
#         380.5567093 ,  384.6378799 ,  388.71905051,  392.80022112,
#         396.88139173,  400.96256234,  405.04373295,  409.12490356,
#         413.20607417,  417.28724478,  421.36841538,  425.44958599,
#         429.5307566 ,  433.61192721,  437.69309782,  441.77426843,
#         445.85543904,  449.93660965,  454.01778026,  458.09895087,
#         462.18012147])

# %%
out[2]
# Out:
# <BarContainer object of 200 artists>

# %%
out[2].get_children()  # میتونی تک تک اون کندل هارو بگیری
# Out:
# [<matplotlib.patches.Rectangle at 0x20e636f9e50>,
#  <matplotlib.patches.Rectangle at 0x20e636f9f90>,
#  <matplotlib.patches.Rectangle at 0x20e636fa0d0>,
#  <matplotlib.patches.Rectangle at 0x20e636fa210>,
#  <matplotlib.patches.Rectangle at 0x20e636fa350>,
#  <matplotlib.patches.Rectangle at 0x20e636fa490>,
#  <matplotlib.patches.Rectangle at 0x20e636fa5d0>,
#  <matplotlib.patches.Rectangle at 0x20e636fa710>,
#  <matplotlib.patches.Rectangle at 0x20e636fa850>,
#  <matplotlib.patches.Rectangle at 0x20e636fa990>,
#  <matplotlib.patches.Rectangle at 0x20e636faad0>,
#  <matplotlib.patches.Rectangle at 0x20e636fac10>,
#  <matplotlib.patches.Rectangle at 0x20e636fad50>,
#  <matplotlib.patches.Rectangle at 0x20e636fae90>,
#  <matplotlib.patches.Rectangle at 0x20e636fafd0>,
#  <matplotlib.patches.Rectangle at 0x20e636fb110>,
#  <matplotlib.patches.Rectangle at 0x20e636fb250>,
#  <matplotlib.patches.Rectangle at 0x20e636fb390>,
#  <matplotlib.patches.Rectangle at 0x20e636fb4d0>,
#  <matplotlib.patches.Rectangle at 0x20e636fb610>,
#  <matplotlib.patches.Rectangle at 0x20e636fb750>,
#  <matplotlib.patches.Rectangle at 0x20e636fb890>,
#  <matplotlib.patches.Rectangle at 0x20e636fb9d0>,
#  <matplotlib.patches.Rectangle at 0x20e636fbb10>,
#  <matplotlib.patches.Rectangle at 0x20e636fbc50>,
#  <matplotlib.patches.Rectangle at 0x20e636fbd90>,
#  <matplotlib.patches.Rectangle at 0x20e636fbed0>,
#  <matplotlib.patches.Rectangle at 0x20e640a8050>,
#  <matplotlib.patches.Rectangle at 0x20e640a8190>,
#  <matplotlib.patches.Rectangle at 0x20e640a82d0>,
#  <matplotlib.patches.Rectangle at 0x20e640a8410>,
#  <matplotlib.patches.Rectangle at 0x20e640a8550>,
#  <matplotlib.patches.Rectangle at 0x20e640a8910>,
#  <matplotlib.patches.Rectangle at 0x20e640a8cd0>,
#  <matplotlib.patches.Rectangle at 0x20e640a8e10>,
#  <matplotlib.patches.Rectangle at 0x20e640a8f50>,
#  <matplotlib.patches.Rectangle at 0x20e640a9090>,
#  <matplotlib.patches.Rectangle at 0x20e640a91d0>,
#  <matplotlib.patches.Rectangle at 0x20e640a9310>,
#  <matplotlib.patches.Rectangle at 0x20e640a9450>,
#  <matplotlib.patches.Rectangle at 0x20e640a87d0>,
#  <matplotlib.patches.Rectangle at 0x20e640a8b90>,
#  <matplotlib.patches.Rectangle at 0x20e640a8a50>,
#  <matplotlib.patches.Rectangle at 0x20e640a8690>,
#  <matplotlib.patches.Rectangle at 0x20e640a9590>,
#  <matplotlib.patches.Rectangle at 0x20e640a96d0>,
#  <matplotlib.patches.Rectangle at 0x20e640a9810>,
#  <matplotlib.patches.Rectangle at 0x20e640a9950>,
#  <matplotlib.patches.Rectangle at 0x20e640a9a90>,
#  <matplotlib.patches.Rectangle at 0x20e640a9bd0>,
#  <matplotlib.patches.Rectangle at 0x20e640a9d10>,
#  <matplotlib.patches.Rectangle at 0x20e640a9e50>,
#  <matplotlib.patches.Rectangle at 0x20e640a9f90>,
#  <matplotlib.patches.Rectangle at 0x20e640aa0d0>,
#  <matplotlib.patches.Rectangle at 0x20e640aa210>,
#  <matplotlib.patches.Rectangle at 0x20e640aa350>,
#  <matplotlib.patches.Rectangle at 0x20e640aa490>,
#  <matplotlib.patches.Rectangle at 0x20e640aa5d0>,
#  <matplotlib.patches.Rectangle at 0x20e640aa710>,
#  <matplotlib.patches.Rectangle at 0x20e640aa850>,
#  <matplotlib.patches.Rectangle at 0x20e640aa990>,
#  <matplotlib.patches.Rectangle at 0x20e640aaad0>,
#  <matplotlib.patches.Rectangle at 0x20e640aac10>,
#  <matplotlib.patches.Rectangle at 0x20e640aad50>,
#  <matplotlib.patches.Rectangle at 0x20e640aae90>,
#  <matplotlib.patches.Rectangle at 0x20e640aafd0>,
#  <matplotlib.patches.Rectangle at 0x20e640ab110>,
#  <matplotlib.patches.Rectangle at 0x20e640ab250>,
#  <matplotlib.patches.Rectangle at 0x20e640ab390>,
#  <matplotlib.patches.Rectangle at 0x20e640ab4d0>,
#  <matplotlib.patches.Rectangle at 0x20e640ab610>,
#  <matplotlib.patches.Rectangle at 0x20e640ab750>,
#  <matplotlib.patches.Rectangle at 0x20e640ab890>,
#  <matplotlib.patches.Rectangle at 0x20e640ab9d0>,
#  <matplotlib.patches.Rectangle at 0x20e640abb10>,
#  <matplotlib.patches.Rectangle at 0x20e640abc50>,
#  <matplotlib.patches.Rectangle at 0x20e640abd90>,
#  <matplotlib.patches.Rectangle at 0x20e640abed0>,
#  <matplotlib.patches.Rectangle at 0x20e640f0050>,
#  <matplotlib.patches.Rectangle at 0x20e640f0190>,
#  <matplotlib.patches.Rectangle at 0x20e640f02d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f0410>,
#  <matplotlib.patches.Rectangle at 0x20e640f0550>,
#  <matplotlib.patches.Rectangle at 0x20e640f0690>,
#  <matplotlib.patches.Rectangle at 0x20e640f07d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f0910>,
#  <matplotlib.patches.Rectangle at 0x20e640f0a50>,
#  <matplotlib.patches.Rectangle at 0x20e640f0b90>,
#  <matplotlib.patches.Rectangle at 0x20e640f0cd0>,
#  <matplotlib.patches.Rectangle at 0x20e640f0e10>,
#  <matplotlib.patches.Rectangle at 0x20e640f0f50>,
#  <matplotlib.patches.Rectangle at 0x20e640f1090>,
#  <matplotlib.patches.Rectangle at 0x20e640f11d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f1310>,
#  <matplotlib.patches.Rectangle at 0x20e640f1450>,
#  <matplotlib.patches.Rectangle at 0x20e640f1590>,
#  <matplotlib.patches.Rectangle at 0x20e640f16d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f1810>,
#  <matplotlib.patches.Rectangle at 0x20e640f1950>,
#  <matplotlib.patches.Rectangle at 0x20e640f1a90>,
#  <matplotlib.patches.Rectangle at 0x20e640f1bd0>,
#  <matplotlib.patches.Rectangle at 0x20e640f1d10>,
#  <matplotlib.patches.Rectangle at 0x20e640f1e50>,
#  <matplotlib.patches.Rectangle at 0x20e640f1f90>,
#  <matplotlib.patches.Rectangle at 0x20e640f20d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f2210>,
#  <matplotlib.patches.Rectangle at 0x20e640f2350>,
#  <matplotlib.patches.Rectangle at 0x20e640f2490>,
#  <matplotlib.patches.Rectangle at 0x20e640f25d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f2710>,
#  <matplotlib.patches.Rectangle at 0x20e640f2850>,
#  <matplotlib.patches.Rectangle at 0x20e640f2990>,
#  <matplotlib.patches.Rectangle at 0x20e640f2ad0>,
#  <matplotlib.patches.Rectangle at 0x20e640f2c10>,
#  <matplotlib.patches.Rectangle at 0x20e640f2d50>,
#  <matplotlib.patches.Rectangle at 0x20e640f2e90>,
#  <matplotlib.patches.Rectangle at 0x20e640f2fd0>,
#  <matplotlib.patches.Rectangle at 0x20e640f3110>,
#  <matplotlib.patches.Rectangle at 0x20e640f3250>,
#  <matplotlib.patches.Rectangle at 0x20e640f3390>,
#  <matplotlib.patches.Rectangle at 0x20e640f34d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f3610>,
#  <matplotlib.patches.Rectangle at 0x20e640f3750>,
#  <matplotlib.patches.Rectangle at 0x20e640f3890>,
#  <matplotlib.patches.Rectangle at 0x20e640f39d0>,
#  <matplotlib.patches.Rectangle at 0x20e640f3b10>,
#  <matplotlib.patches.Rectangle at 0x20e640f3c50>,
#  <matplotlib.patches.Rectangle at 0x20e640f3d90>,
#  <matplotlib.patches.Rectangle at 0x20e640f3ed0>,
#  <matplotlib.patches.Rectangle at 0x20e64154050>,
#  <matplotlib.patches.Rectangle at 0x20e64154190>,
#  <matplotlib.patches.Rectangle at 0x20e641542d0>,
#  <matplotlib.patches.Rectangle at 0x20e64154410>,
#  <matplotlib.patches.Rectangle at 0x20e64154550>,
#  <matplotlib.patches.Rectangle at 0x20e64154690>,
#  <matplotlib.patches.Rectangle at 0x20e641547d0>,
#  <matplotlib.patches.Rectangle at 0x20e64154910>,
#  <matplotlib.patches.Rectangle at 0x20e64154a50>,
#  <matplotlib.patches.Rectangle at 0x20e64154b90>,
#  <matplotlib.patches.Rectangle at 0x20e64154cd0>,
#  <matplotlib.patches.Rectangle at 0x20e64154e10>,
#  <matplotlib.patches.Rectangle at 0x20e64154f50>,
#  <matplotlib.patches.Rectangle at 0x20e64155090>,
#  <matplotlib.patches.Rectangle at 0x20e641551d0>,
#  <matplotlib.patches.Rectangle at 0x20e64155310>,
#  <matplotlib.patches.Rectangle at 0x20e64155450>,
#  <matplotlib.patches.Rectangle at 0x20e64155590>,
#  <matplotlib.patches.Rectangle at 0x20e641556d0>,
#  <matplotlib.patches.Rectangle at 0x20e64155810>,
#  <matplotlib.patches.Rectangle at 0x20e64155950>,
#  <matplotlib.patches.Rectangle at 0x20e64155a90>,
#  <matplotlib.patches.Rectangle at 0x20e64155bd0>,
#  <matplotlib.patches.Rectangle at 0x20e64155d10>,
#  <matplotlib.patches.Rectangle at 0x20e64155e50>,
#  <matplotlib.patches.Rectangle at 0x20e64155f90>,
#  <matplotlib.patches.Rectangle at 0x20e641560d0>,
#  <matplotlib.patches.Rectangle at 0x20e64156210>,
#  <matplotlib.patches.Rectangle at 0x20e64156350>,
#  <matplotlib.patches.Rectangle at 0x20e64156490>,
#  <matplotlib.patches.Rectangle at 0x20e641565d0>,
#  <matplotlib.patches.Rectangle at 0x20e64156710>,
#  <matplotlib.patches.Rectangle at 0x20e64156850>,
#  <matplotlib.patches.Rectangle at 0x20e64156990>,
#  <matplotlib.patches.Rectangle at 0x20e64156ad0>,
#  <matplotlib.patches.Rectangle at 0x20e64156c10>,
#  <matplotlib.patches.Rectangle at 0x20e64156d50>,
#  <matplotlib.patches.Rectangle at 0x20e64156e90>,
#  <matplotlib.patches.Rectangle at 0x20e64156fd0>,
#  <matplotlib.patches.Rectangle at 0x20e64157110>,
#  <matplotlib.patches.Rectangle at 0x20e64157250>,
#  <matplotlib.patches.Rectangle at 0x20e64157390>,
#  <matplotlib.patches.Rectangle at 0x20e641574d0>,
#  <matplotlib.patches.Rectangle at 0x20e64157610>,
#  <matplotlib.patches.Rectangle at 0x20e64157750>,
#  <matplotlib.patches.Rectangle at 0x20e64157890>,
#  <matplotlib.patches.Rectangle at 0x20e641579d0>,
#  <matplotlib.patches.Rectangle at 0x20e64157b10>,
#  <matplotlib.patches.Rectangle at 0x20e64157c50>,
#  <matplotlib.patches.Rectangle at 0x20e64157d90>,
#  <matplotlib.patches.Rectangle at 0x20e64157ed0>,
#  <matplotlib.patches.Rectangle at 0x20e6531c050>,
#  <matplotlib.patches.Rectangle at 0x20e6531c190>,
#  <matplotlib.patches.Rectangle at 0x20e6531c2d0>,
#  <matplotlib.patches.Rectangle at 0x20e6531c410>,
#  <matplotlib.patches.Rectangle at 0x20e6531c550>,
#  <matplotlib.patches.Rectangle at 0x20e6531c690>,
#  <matplotlib.patches.Rectangle at 0x20e6531c7d0>,
#  <matplotlib.patches.Rectangle at 0x20e6531c910>,
#  <matplotlib.patches.Rectangle at 0x20e6531ca50>,
#  <matplotlib.patches.Rectangle at 0x20e63ae5a90>,
#  <matplotlib.patches.Rectangle at 0x20e63ae6350>,
#  <matplotlib.patches.Rectangle at 0x20e63ae5d10>,
#  <matplotlib.patches.Rectangle at 0x20e63ae56d0>,
#  <matplotlib.patches.Rectangle at 0x20e63ae5810>,
#  <matplotlib.patches.Rectangle at 0x20e63ae5950>,
#  <matplotlib.patches.Rectangle at 0x20e63ae6210>,
#  <matplotlib.patches.Rectangle at 0x20e63ae6ad0>,
#  <matplotlib.patches.Rectangle at 0x20e63ae6490>,
#  <matplotlib.patches.Rectangle at 0x20e63ae5e50>,
#  <matplotlib.patches.Rectangle at 0x20e63ae5310>]

# %%
data = np.random.normal(0,100,(10000,))
out = plt.hist(data,bins=20,density=True)
r = out[2].get_children()[10]
r.set_color('r')

# %% [markdown]
# ---

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %%
data = np.random.normal(0,100,(5,5))
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('./Iris.csv').drop('Id',axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)   # دو به دو نسبت به خودش رسم میکنه

# %%
sns.pairplot(df,hue='Species')

# %%
sns.scatterplot(df,x='SepalLengthCm',y='PetalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
c = df['Species'].astype('category')
c
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: category
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
c = df['Species'].astype('category').cat.codes     # code miad adad mikone
plt.scatter(df['SepalLengthCm'].values,df['PetalLengthCm'].values,c = c)

# %% [markdown]
# ---

# %%
plt.figure(figsize=(15,7),dpi=72)   #dpi yani be ezay har inch 20 ta noqte bekesh
# chap adi 300

x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))
plt.plot(x,y)
plt.plot(x,y_2)

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y_2,'b')

# %%
x= np.linspace(0,360,50)
y = np.sin(np.radians(x))
y_2 = np.cos(np.radians(x))

plt.figure(figsize=(15,7),dpi=72)
plt.subplot(2,1,1)
plt.plot(x,y,'r')
plt.subplot(2,1,2)
plt.plot(x,y_2,'b')

# %%
from PIL import Image
im  =np.array(Image.open('./1.jpg'))

# %%
plt.figure(figsize=(20, 7), dpi=72)

plt.subplot(1, 4, 1)
plt.imshow(im)
plt.title('RGB')

plt.subplot(1, 4, 2)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(1, 4, 3)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(1, 4, 4) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
plt.figure(figsize=(25, 7), dpi=72)

plt.subplot(2,3, 2)
plt.imshow(im)
plt.title('RGB')
plt.xticks([0,im.shape[1]])
plt.yticks([0,im.shape[0]])

plt.subplot(2,3, 4)


plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 0], "Reds")
plt.title('Reds')


plt.subplot(2,3, 5)
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 1], "Greens")
plt.title('Greens')


plt.subplot(2,3, 6) 
plt.xticks([])
plt.yticks([])
plt.imshow(im[:, :, 2], "Blues")
plt.title('Blues')



plt.suptitle('IMAGE')
# Out:
# Text(0.5, 0.98, 'IMAGE')

# %%
x= np.linspace(1,360,100)
y = np.sin(np.radians(x))
y_2 = np.log(x)


plt.plot(x,y,'r')

plt.plot(x,y_2,'b')

# %%
x= np.linspace(1,360,100)
y = np.sin(np.radians(x))
y_2 = np.log(x)

fig,ax = plt.subplots()


ax.plot(x,y,'r')
ax.set_ylabel('$sin(x)$')
ax2 = ax.twinx() # کپی از نمودار با x مشترک
ax2.plot(x,y_2,'b')
ax2.set_ylabel('$log(x)$')
# Out:
# Text(0, 0.5, '$log(x)$')
